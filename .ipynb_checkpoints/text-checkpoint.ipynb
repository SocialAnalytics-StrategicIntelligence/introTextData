# %% [markdown]
# <img src="https://i.imgur.com/6U6q5jQ.png"/>
#
# # Text as Data
#
# Let me get use some old tweets from Donald Trump:

# %%
import pandas as pd
import os

trumpFile=os.path.join('textData','trumps.csv')
allTweets=pd.read_csv(trumpFile)
allTweets
# Out:
#               created_at                                               text  \
# 0    2020-08-13 23:26:50  .@DonYoungAK really produces for Alaska. He is...
# 1    2020-08-13 23:23:26  ...She will be a great Senator, and has my Com...
# 2    2020-08-13 23:23:25  .@CynthiaMLummis is a friend of mine and a gre...
# 3    2020-08-13 21:27:36  LIVE: President @realDonaldTrump holds a news ...
# 4    2020-08-13 18:59:29                            https://t.co/ymvtIzQqoR
# ..                   ...                                                ...
# 194  2020-08-04 23:00:40  Reopening Our Schools: @realDonaldTrump says s...
# 195  2020-08-04 23:00:38  Reopening America: President @realDonaldTrump ...
# 196  2020-08-04 23:00:15  We have far and away the most robust testing c...
# 197  2020-08-04 22:48:35  "As we shelter those at high risk, we are also...
# 198  2020-08-04 22:46:07  "Thanks to our major advances in treatment, we...
#
#      is_retweet  favorite_count  retweet_count  Hour  Day        Date
# 0         False           18714           5305    23    5  2020-08-13
# 1         False           14946           3490    23    5  2020-08-13
# 2         False           32586           8584    23    5  2020-08-13
# 3          True               0           5917    21    5  2020-08-13
# 4         False           20131           5303    18    5  2020-08-13
# ..          ...             ...            ...   ...  ...         ...
# 194        True               0           7205    23    3  2020-08-04
# 195        True               0           7603    23    3  2020-08-04
# 196        True               0           5717    23    3  2020-08-04
# 197        True               0           5414    22    3  2020-08-04
# 198        True               0           5626    22    3  2020-08-04
#
# [199 rows x 8 columns]

# %% [markdown]
# Let me subset the dataframe, just to keep the non retweets:

# %%
DTtweets=allTweets[~allTweets.is_retweet]
DTtweets.reset_index(drop=True,inplace=True)

# %% [markdown]
# ## Tokenization
#
# A key step for text analytics is tokenization: where the text is broken into smaller pieces.
#
# We can use:
#
# - NLTK library:

# %%
import nltk
from nltk.tokenize import word_tokenize

DTtweets['text'].apply(nltk.word_tokenize)
# Out:
# 0      [., @, DonYoungAK, really, produces, for, Alas...
# 1      [..., She, will, be, a, great, Senator, ,, and...
# 2      [., @, CynthiaMLummis, is, a, friend, of, mine...
# 3                          [https, :, //t.co/ymvtIzQqoR]
# 4                          [https, :, //t.co/BY6PrMRmqJ]
#                              ...
# 116    [For, those, that, thought, I, wasn, ’, t, int...
# 117    [A, great, race, run, by, Roger, against, a, v...
# 118    [There, is, TREMENDOUS, Lawlessness, in, Ameri...
# 119                        [https, :, //t.co/JDS4zUXXJG]
# 120    [Great, meeting, today, with, the, CoronaVirus...
# Name: text, Length: 121, dtype: object

# %% [markdown]
# * Pandas string functions:

# %%
DTtweets.text.str.split('\s')
# Out:
# 0      [.@DonYoungAK, really, produces, for, Alaska.,...
# 1      [...She, will, be, a, great, Senator,, and, ha...
# 2      [.@CynthiaMLummis, is, a, friend, of, mine, an...
# 3                              [https://t.co/ymvtIzQqoR]
# 4                              [https://t.co/BY6PrMRmqJ]
#                              ...
# 116    [For, those, that, thought, I, wasn’t, into, t...
# 117    [A, great, race, run, by, Roger, against, a, v...
# 118    [There, is, TREMENDOUS, Lawlessness, in, Ameri...
# 119                            [https://t.co/JDS4zUXXJG]
# 120    [Great, meeting, today, with, the, CoronaVirus...
# Name: text, Length: 121, dtype: object

# %% [markdown]
# The basic Pandas seems more convenient. Then, we simply create a series where each cell is a token (word):

# %%
import numpy as np

wordInSeries=pd.Series(np.concatenate(DTtweets.text.str.split('\s')))
wordInSeries
# Out:
# 0                   .@DonYoungAK
# 1                         really
# 2                       produces
# 3                            for
# 4                        Alaska.
#                   ...
# 2915                        Stay
# 2916                    informed
# 2917                         at:
# 2918    https://t.co/p9j7kZsD7b.
# 2919     https://t.co/nnnUHCzOLV
# Length: 2920, dtype: object

# %% [markdown]
# ### Cleaning the tokens

# %%
wordInSeries=wordInSeries[~wordInSeries.str.startswith('http')].reset_index(drop=True)
wordInSeries
# Out:
# 0       .@DonYoungAK
# 1             really
# 2           produces
# 3                for
# 4            Alaska.
#             ...
# 2861            Oval
# 2862         Office.
# 2863            Stay
# 2864        informed
# 2865             at:
# Length: 2866, dtype: object

# %%
wordInSeries=wordInSeries.str.replace('[^\x01-\x7F]','')
wordInSeries=wordInSeries.str.replace('&amp;','and')
wordInSeries=wordInSeries.str.replace('&lt;|&gt;','')
wordInSeries
# Out:
# 0       .@DonYoungAK
# 1             really
# 2           produces
# 3                for
# 4            Alaska.
#             ...
# 2861            Oval
# 2862         Office.
# 2863            Stay
# 2864        informed
# 2865             at:
# Length: 2866, dtype: object

# %%
# punctuation
import string
PUNCs=string.punctuation # '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
wordInSeries=wordInSeries.str.replace('['+PUNCs+']', '',regex=True)

# all to lower case
wordInSeries=wordInSeries.str.lower()
wordInSeries
# Out:
# 0       donyoungak
# 1           really
# 2         produces
# 3              for
# 4           alaska
#            ...
# 2861          oval
# 2862        office
# 2863          stay
# 2864      informed
# 2865            at
# Length: 2866, dtype: object

# %% [markdown]
# ### Relevant tokens
#
# It is difficult to know what tokens should not be analyzed. Let's count the current ones:

# %%
wordInSeries.value_counts()
# Out:
# the           136
# and            91
# to             79
# in             67
# of             58
#              ...
# plague          1
# cops            1
# sleazebags      1
# highest         1
# informed        1
# Name: count, Length: 1027, dtype: int64

# %% [markdown]
# We could agree that simple sintactic components like determinatives, conjunctions, or prepositions do carry much information. Most of these elements are known as **STOPWORDS**.  We use them to reduce our tokens:

# %%
from nltk.corpus import stopwords
STOPS = stopwords.words('english')


wordInSeries=wordInSeries[~wordInSeries.isin(STOPS)].reset_index(drop=True)
wordInSeries
# Out:
# 0       donyoungak
# 1           really
# 2         produces
# 3           alaska
# 4       incredible
#            ...
# 1681         force
# 1682          oval
# 1683        office
# 1684          stay
# 1685      informed
# Length: 1686, dtype: object

# %% [markdown]
# ## Word Frequency
#
# We could keep prepare a frequency with the words remaining:

# %%
wordInSeries.value_counts()
# Out:
# great       27
# bus         20
# people      18
# usdot       17
# big         15
#             ..
# men          1
# women        1
# fighting     1
# plague       1
# informed     1
# Name: count, Length: 927, dtype: int64

# %% [markdown]
# Let's see the distribution of counts:

# %%
wordInSeries.value_counts().plot(logy=True, kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
FrequencyTrumpTokens=wordInSeries.value_counts()[wordInSeries.value_counts()>5]
FrequencyTrumpTokens
# Out:
# great              27
# bus                20
# people             18
# usdot              17
# big                15
# service            14
# infrastructure     14
# support            13
# state              12
# complete           12
# news               12
# federal            11
# endorsement        11
# total              10
# funds              10
# joe                10
# congratulations     9
#                     8
# biden               8
# thank               8
# improvements        8
# happy               7
# president           7
# fake                7
# good                7
# new                 7
# states              7
# second              7
# first               7
# way                 6
# vets                6
# funding             6
# would               6
# amendment           6
# one                 6
# win                 6
# strong              6
# congressman         6
# Name: count, dtype: int64

# %% [markdown]
# We have series, let me have a dict:

# %%
FrequencyTrumpTokens.to_dict()
# Out:
# {'great': 27,
#  'bus': 20,
#  'people': 18,
#  'usdot': 17,
#  'big': 15,
#  'service': 14,
#  'infrastructure': 14,
#  'support': 13,
#  'state': 12,
#  'complete': 12,
#  'news': 12,
#  'federal': 11,
#  'endorsement': 11,
#  'total': 10,
#  'funds': 10,
#  'joe': 10,
#  'congratulations': 9,
#  '': 8,
#  'biden': 8,
#  'thank': 8,
#  'improvements': 8,
#  'happy': 7,
#  'president': 7,
#  'fake': 7,
#  'good': 7,
#  'new': 7,
#  'states': 7,
#  'second': 7,
#  'first': 7,
#  'way': 6,
#  'vets': 6,
#  'funding': 6,
#  'would': 6,
#  'amendment': 6,
#  'one': 6,
#  'win': 6,
#  'strong': 6,
#  'congressman': 6}

# %% [markdown]
# ### Plotting

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

import matplotlib.pyplot as plt
from wordcloud import WordCloud
 
wc1 = WordCloud(background_color='white')
wc1.generate_from_frequencies(frequencies=FrequencyTrumpTokens.to_dict())
plt.figure()
plt.imshow(wc1, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wc2 = WordCloud(background_color='white',
                colormap="Reds")
wc2.generate_from_frequencies(frequencies=FrequencyTrumpTokens.to_dict())
plt.figure()
plt.imshow(wc2, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
f = open("textData/sometext.txt", "r")

textFile=os.path.join('textData','sometext.txt')
allText=pd.read_table(textFile,header=None)
allText
# Out:
#                                                     0
# 0   Seattle is under siege. Over the past five yea...
# 1   At the same time, according to the Puget Sound...
# 2   Over the past year, I’ve spent time at city co...
# 3   Seattle has long been known as one of America’...
# 4   On the surface, this argument has its own inte...
# 5   Even in a pricey city like Seattle, most worki...
# 6   Using homelessness as a symbol of “capitalism’...
# 7   What the socialists won’t, or can’t, see is th...
# 8   The stubborn reality is that Seattle is expens...
# 9   “What the socialists won’t, or can’t, see is t...
# 10  The compassion brigades are the moral crusader...
# 11  O’Brien and his supporters have constructed an...
# 12  The second key myth is that the homeless are “...
# 13  The third myth: O’Brien and his allies argue t...
# 14  The homeless mythology is not merely anti-fact...
# 15  Yet the compassion advocates man the barricade...
# 16  With more than $1 billion spent on homelessnes...
# 17  It wasn’t always this way. When I spoke with E...
# 18  The deeper problem is that social policies hav...
# 19  Their latest scheme in Seattle is to build cit...
# 20  Even worse, SHARE, which runs the Licton Sprin...
# 21  Ultimately, the homeless-industrial complex is...
# 22  Despite repeated warnings from Seattle’s own h...
# 23  What I call the addiction evangelists make up ...
# 24  Their leading proponent is Shilo Murphy, a her...
# 25  Incredibly, Murphy has become a player in Seat...
# 26  Harm reduction has had notable success in coun...
# 27  “What I call the addiction evangelists include...
# 28  The question almost never asked about harm red...
# 29  In Seattle, the influx has already begun. Acco...
# 30  Yet the addiction evangelists are making gains...
# 31  In 2005, the top experts in Seattle and King C...
# 32  Unfortunately, Adrienne Quinn, the new boss of...
# 33  The problem is not Seattle’s alone: the United...
# 34  Homelessness is a condition of disengagement f...
# 35  The best way to prevent homelessness isn’t to ...
# 36  In the near term, cities like Seattle, Portlan...
# 37  Representing homelessness as a symbol of capit...
# 38  Representing homelessness as a symbol of capit...
# 39  Encouragingly, citizens and local governments ...
# 40  In Seattle, Mayor Jenny Durkan, who made her r...
# 41  In San Diego, for instance, city officials and...
# 42  In Houston, local leaders have reduced homeles...
# 43  Seattle and King County currently spend nearly...
# 44  Seattle must break up its homeless-industrial ...
# 45  Ultimately, the success or failure of local go...

# %%
allText[0]=allText[0].str.lower()

# %%
from nltk import bigrams

theBigrams=[bigrams(eachTW.split()) for eachTW in allText[0]]


# list of all bigrams
from itertools import chain

pairWords = list(chain(*theBigrams))

pairWords
# Out:
# [('seattle', 'is'),
#  ('is', 'under'),
#  ('under', 'siege.'),
#  ('siege.', 'over'),
#  ('over', 'the'),
#  ('the', 'past'),
#  ('past', 'five'),
#  ('five', 'years,'),
#  ('years,', 'the'),
#  ('the', 'emerald'),
#  ('emerald', 'city'),
#  ('city', 'has'),
#  ('has', 'seen'),
#  ('seen', 'an'),
#  ('an', 'explosion'),
#  ('explosion', 'of'),
#  ('of', 'homelessness,'),
#  ('homelessness,', 'crime,'),
#  ('crime,', 'and'),
#  ('and', 'addiction.'),
#  ('addiction.', 'in'),
#  ('in', 'its'),
#  ('its', '2017'),
#  ('2017', 'point-in-time'),
#  ('point-in-time', 'count'),
#  ('count', 'of'),
#  ('of', 'the'),
#  ('the', 'homeless,'),
#  ('homeless,', 'king'),
#  ('king', 'county'),
#  ('county', 'social-services'),
#  ('social-services', 'agency'),
#  ('agency', 'all'),
#  ('all', 'home'),
#  ('home', 'found'),
#  ('found', '11,643'),
#  ('11,643', 'people'),
#  ('people', 'sleeping'),
#  ('sleeping', 'in'),
#  ('in', 'tents,'),
#  ('tents,', 'cars,'),
#  ('cars,', 'and'),
#  ('and', 'emergency'),
#  ('emergency', 'shelters.'),
#  ('shelters.', 'property'),
#  ('property', 'crime'),
#  ('crime', 'has'),
#  ('has', 'risen'),
#  ('risen', 'to'),
#  ('to', 'a'),
#  ('a', 'rate'),
#  ('rate', 'two'),
#  ('two', 'and'),
#  ('and', 'a'),
#  ('a', 'half'),
#  ('half', 'times'),
#  ('times', 'higher'),
#  ('higher', 'than'),
#  ('than', 'los'),
#  ('los', 'angeles’s'),
#  ('angeles’s', 'and'),
#  ('and', 'four'),
#  ('four', 'times'),
#  ('times', 'higher'),
#  ('higher', 'than'),
#  ('than', 'new'),
#  ('new', 'york'),
#  ('york', 'city’s.'),
#  ('city’s.', 'cleanup'),
#  ('cleanup', 'crews'),
#  ('crews', 'pick'),
#  ('pick', 'up'),
#  ('up', 'tens'),
#  ('tens', 'of'),
#  ('of', 'thousands'),
#  ('thousands', 'of'),
#  ('of', 'dirty'),
#  ('dirty', 'needles'),
#  ('needles', 'from'),
#  ('from', 'city'),
#  ('city', 'streets'),
#  ('streets', 'and'),
#  ('and', 'parks'),
#  ('parks', 'every'),
#  ('every', 'year.'),
#  ('at', 'the'),
#  ('the', 'same'),
#  ('same', 'time,'),
#  ('time,', 'according'),
#  ('according', 'to'),
#  ('to', 'the'),
#  ('the', 'puget'),
#  ('puget', 'sound'),
#  ('sound', 'business'),
#  ('business', 'journal,'),
#  ('journal,', 'the'),
#  ('the', 'seattle'),
#  ('seattle', 'metro'),
#  ('metro', 'area'),
#  ('area', 'spends'),
#  ('spends', 'more'),
#  ('more', 'than'),
#  ('than', '$1'),
#  ('$1', 'billion'),
#  ('billion', 'fighting'),
#  ('fighting', 'homelessness'),
#  ('homelessness', 'every'),
#  ('every', 'year.'),
#  ('year.', 'that’s'),
#  ('that’s', 'nearly'),
#  ('nearly', '$100,000'),
#  ('$100,000', 'for'),
#  ('for', 'every'),
#  ('every', 'homeless'),
#  ('homeless', 'man,'),
#  ('man,', 'woman,'),
#  ('woman,', 'and'),
#  ('and', 'child'),
#  ('child', 'in'),
#  ('in', 'king'),
#  ('king', 'county,'),
#  ('county,', 'yet'),
#  ('yet', 'the'),
#  ('the', 'crisis'),
#  ('crisis', 'seems'),
#  ('seems', 'only'),
#  ('only', 'to'),
#  ('to', 'have'),
#  ('have', 'deepened,'),
#  ('deepened,', 'with'),
#  ('with', 'more'),
#  ('more', 'addiction,'),
#  ('addiction,', 'more'),
#  ('more', 'crime,'),
#  ('crime,', 'and'),
#  ('and', 'more'),
#  ('more', 'tent'),
#  ('tent', 'encampments'),
#  ('encampments', 'in'),
#  ('in', 'residential'),
#  ('residential', 'neighborhoods.'),
#  ('neighborhoods.', 'by'),
#  ('by', 'any'),
#  ('any', 'measure,'),
#  ('measure,', 'the'),
#  ('the', 'city’s'),
#  ('city’s', 'efforts'),
#  ('efforts', 'are'),
#  ('are', 'not'),
#  ('not', 'working.'),
#  ('over', 'the'),
#  ('the', 'past'),
#  ('past', 'year,'),
#  ('year,', 'i’ve'),
#  ('i’ve', 'spent'),
#  ('spent', 'time'),
#  ('time', 'at'),
#  ('at', 'city'),
#  ('city', 'council'),
#  ('council', 'meetings,'),
#  ('meetings,', 'political'),
#  ('political', 'rallies,'),
#  ('rallies,', 'homeless'),
#  ('homeless', 'encampments,'),
#  ('encampments,', 'and'),
#  ('and', 'rehabilitation'),
#  ('rehabilitation', 'facilities,'),
#  ('facilities,', 'trying'),
#  ('trying', 'to'),
#  ('to', 'understand'),
#  ('understand', 'how'),
#  ('how', 'the'),
#  ('the', 'government'),
#  ('government', 'can'),
#  ('can', 'spend'),
#  ('spend', 'so'),
#  ('so', 'much'),
#  ('much', 'money'),
#  ('money', 'with'),
#  ('with', 'so'),
#  ('so', 'little'),
#  ('little', 'effect.'),
#  ('effect.', 'while'),
#  ('while', 'most'),
#  ('most', 'of'),
#  ('of', 'the'),
#  ('the', 'debate'),
#  ('debate', 'has'),
#  ('has', 'focused'),
#  ('focused', 'on'),
#  ('on', 'tactical'),
#  ('tactical', 'policy'),
#  ('policy', 'questions'),
#  ('questions', '(build'),
#  ('(build', 'more'),
#  ('more', 'shelters?'),
#  ('shelters?', 'open'),
#  ('open', 'supervised'),
#  ('supervised', 'injection'),
#  ('injection', 'sites?),'),
#  ('sites?),', 'the'),
#  ('the', 'real'),
#  ('real', 'battle'),
#  ('battle', 'isn’t'),
#  ('isn’t', 'being'),
#  ('being', 'waged'),
#  ('waged', 'in'),
#  ('in', 'the'),
#  ('the', 'tents,'),
#  ('tents,', 'under'),
#  ('under', 'the'),
#  ('the', 'bridges,'),
#  ('bridges,', 'or'),
#  ('or', 'in'),
#  ('in', 'the'),
#  ('the', 'corridors'),
#  ('corridors', 'of'),
#  ('of', 'city'),
#  ('city', 'hall'),
#  ('hall', 'but'),
#  ('but', 'in'),
#  ('in', 'the'),
#  ('the', 'realm'),
#  ('realm', 'of'),
#  ('of', 'ideas,'),
#  ('ideas,', 'where,'),
#  ('where,', 'for'),
#  ('for', 'now,'),
#  ('now,', 'four'),
#  ('four', 'ideological'),
#  ('ideological', 'power'),
#  ('power', 'centers'),
#  ('centers', 'frame'),
#  ('frame', 'seattle’s'),
#  ('seattle’s', 'homelessness'),
#  ('homelessness', 'debate.'),
#  ('debate.', 'i’ll'),
#  ('i’ll', 'identify'),
#  ('identify', 'them'),
#  ('them', 'as'),
#  ('as', 'the'),
#  ('the', 'socialists,'),
#  ('socialists,', 'the'),
#  ('the', 'compassion'),
#  ('compassion', 'brigades,'),
#  ('brigades,', 'the'),
#  ('the', 'homeless-industrial'),
#  ('homeless-industrial', 'complex,'),
#  ('complex,', 'and'),
#  ('and', 'the'),
#  ('the', 'addiction'),
#  ('addiction', 'evangelists.'),
#  ('evangelists.', 'together,'),
#  ('together,', 'they'),
#  ('they', 'have'),
#  ('have', 'dominated'),
#  ('dominated', 'the'),
#  ('the', 'local'),
#  ('local', 'policy'),
#  ('policy', 'discussion,'),
#  ('discussion,', 'diverted'),
#  ('diverted', 'hundreds'),
#  ('hundreds', 'of'),
#  ('of', 'millions'),
#  ('millions', 'of'),
#  ('of', 'dollars'),
#  ('dollars', 'toward'),
#  ('toward', 'favored'),
#  ('favored', 'projects,'),
#  ('projects,', 'and'),
#  ('and', 'converted'),
#  ('converted', 'many'),
#  ('many', 'well-intentioned'),
#  ('well-intentioned', 'voters'),
#  ('voters', 'to'),
#  ('to', 'the'),
#  ('the', 'politics'),
#  ('politics', 'of'),
#  ('of', 'unlimited'),
#  ('unlimited', 'compassion.'),
#  ('compassion.', 'if'),
#  ('if', 'we'),
#  ('we', 'want'),
#  ('want', 'to'),
#  ('to', 'break'),
#  ('break', 'through'),
#  ('through', 'the'),
#  ('the', 'failed'),
#  ('failed', 'status'),
#  ('status', 'quo'),
#  ('quo', 'on'),
#  ('on', 'homelessness'),
#  ('homelessness', 'in'),
#  ('in', 'places'),
#  ('places', 'like'),
#  ('like', 'seattle—and'),
#  ('seattle—and', 'in'),
#  ('in', 'portland,'),
#  ('portland,', 'san'),
#  ('san', 'francisco,'),
#  ('francisco,', 'and'),
#  ('and', 'los'),
#  ('los', 'angeles,'),
#  ('angeles,', 'too—we'),
#  ('too—we', 'must'),
#  ('must', 'first'),
#  ('first', 'map'),
#  ('map', 'the'),
#  ('the', 'ideological'),
#  ('ideological', 'battlefield,'),
#  ('battlefield,', 'identify'),
#  ('identify', 'the'),
#  ('the', 'flaws'),
#  ('flaws', 'in'),
#  ('in', 'our'),
#  ('our', 'current'),
#  ('current', 'policies,'),
#  ('policies,', 'and'),
#  ('and', 'rethink'),
#  ('rethink', 'our'),
#  ('our', 'assumptions.'),
#  ('seattle', 'has'),
#  ('has', 'long'),
#  ('long', 'been'),
#  ('been', 'known'),
#  ('known', 'as'),
#  ('as', 'one'),
#  ('one', 'of'),
#  ('of', 'america’s'),
#  ('america’s', 'most'),
#  ('most', 'liberal'),
#  ('liberal', 'locales,'),
#  ('locales,', 'but'),
#  ('but', 'in'),
#  ('in', 'recent'),
#  ('recent', 'years,'),
#  ('years,', 'the'),
#  ('the', 'city'),
#  ('city', 'has'),
#  ('has', 'marched'),
#  ('marched', 'even'),
#  ('even', 'further'),
#  ('further', 'left'),
#  ('left', 'as'),
#  ('as', 'socialists,'),
#  ('socialists,', 'once'),
#  ('once', 'relegated'),
#  ('relegated', 'to'),
#  ('to', 'the'),
#  ('the', 'margins,'),
#  ('margins,', 'have'),
#  ('have', 'declared'),
#  ('declared', 'war'),
#  ('war', 'on'),
#  ('on', 'the'),
#  ('the', 'democratic'),
#  ('democratic', 'establishment.'),
#  ('establishment.', 'socialist'),
#  ('socialist', 'alternative'),
#  ('alternative', 'city'),
#  ('city', 'councilwoman'),
#  ('councilwoman', 'kshama'),
#  ('kshama', 'sawant'),
#  ('sawant', 'claims'),
#  ('claims', 'that'),
#  ('that', 'the'),
#  ('the', 'city’s'),
#  ('city’s', 'homelessness'),
#  ('homelessness', 'crisis'),
#  ('crisis', 'is'),
#  ('is', 'the'),
#  ('the', 'inevitable'),
#  ('inevitable', 'result'),
#  ('result', 'of'),
#  ('of', 'the'),
#  ('the', 'amazon'),
#  ('amazon', 'boom,'),
#  ('boom,', 'greedy'),
#  ('greedy', 'landlords,'),
#  ('landlords,', 'and'),
#  ('and', 'rapidly'),
#  ('rapidly', 'increasing'),
#  ('increasing', 'rents.'),
#  ('rents.', 'as'),
#  ('as', 'she'),
#  ('she', 'told'),
#  ('told', 'street'),
#  ('street', 'roots'),
#  ('roots', 'news:'),
#  ('news:', '“the'),
#  ('“the', 'explosion'),
#  ('explosion', 'of'),
#  ('of', 'the'),
#  ('the', 'homelessness'),
#  ('homelessness', 'crisis'),
#  ('crisis', 'is'),
#  ('is', 'a'),
#  ('a', 'symptom'),
#  ('symptom', 'of'),
#  ('of', 'how'),
#  ('how', 'deeply'),
#  ('deeply', 'dysfunctional'),
#  ('dysfunctional', 'capitalism'),
#  ('capitalism', 'is'),
#  ('is', 'and'),
#  ('and', 'also'),
#  ('also', 'how'),
#  ('how', 'much'),
#  ('much', 'worse'),
#  ('worse', 'living'),
#  ('living', 'standards'),
#  ('standards', 'have'),
#  ('have', 'gotten'),
#  ('gotten', 'with'),
#  ('with', 'the'),
#  ('the', 'last'),
#  ('last', 'several'),
#  ('several', 'decades.”'),
#  ('decades.”', 'the'),
#  ('the', 'capitalists'),
#  ('capitalists', 'of'),
#  ('of', 'amazon,'),
#  ('amazon,', 'starbucks,'),
#  ('starbucks,', 'microsoft,'),
#  ('microsoft,', 'and'),
#  ('and', 'boeing,'),
#  ('boeing,', 'in'),
#  ('in', 'her'),
#  ('her', 'marxian'),
#  ('marxian', 'optic,'),
#  ('optic,', 'generate'),
#  ('generate', 'enormous'),
#  ('enormous', 'wealth'),
#  ('wealth', 'for'),
#  ('for', 'themselves,'),
#  ('themselves,', 'drive'),
#  ('drive', 'up'),
#  ('up', 'housing'),
#  ('housing', 'prices,'),
#  ('prices,', 'and'),
#  ('and', 'push'),
#  ('push', 'the'),
#  ('the', 'working'),
#  ('working', 'class'),
#  ('class', 'toward'),
#  ('toward', 'poverty'),
#  ('poverty', 'and'),
#  ('and', 'despair—and,'),
#  ('despair—and,', 'too'),
#  ('too', 'often,'),
#  ('often,', 'onto'),
#  ('onto', 'the'),
#  ('the', 'streets.'),
#  ('on', 'the'),
#  ('the', 'surface,'),
#  ('surface,', 'this'),
#  ('this', 'argument'),
#  ('argument', 'has'),
#  ('has', 'its'),
#  ('its', 'own'),
#  ('own', 'internal'),
#  ('internal', 'logic.'),
#  ('logic.', 'advocates'),
#  ('advocates', 'point'),
#  ('point', 'to'),
#  ('to', 'zillow'),
#  ('zillow', 'and'),
#  ('and', 'mckinsey'),
#  ('mckinsey', 'studies'),
#  ('studies', 'that'),
#  ('that', 'show'),
#  ('show', 'a'),
#  ('a', 'high'),
#  ('high', 'correlation'),
#  ('correlation', 'between'),
#  ('between', 'rent'),
#  ('rent', 'hikes'),
#  ('hikes', 'and'),
#  ('and', 'homelessness'),
#  ('homelessness', 'in'),
#  ('in', 'seattle,'),
#  ('seattle,', 'for'),
#  ('for', 'example.'),
#  ('example.', 'but'),
#  ('but', 'correlation'),
#  ('correlation', 'is'),
#  ('is', 'not'),
#  ('not', 'causation,'),
#  ('causation,', 'and'),
#  ('and', 'the'),
#  ('the', 'survey'),
#  ('survey', 'data'),
#  ('data', 'paint'),
#  ('paint', 'a'),
#  ('a', 'remarkably'),
#  ('remarkably', 'different'),
#  ('different', 'picture.'),
#  ('picture.', 'according'),
#  ('according', 'to'),
#  ('to', 'king'),
#  ('king', 'county’s'),
#  ('county’s', 'point-in-time'),
#  ('point-in-time', 'study,'),
#  ('study,', 'only'),
#  ('only', '6'),
#  ('6', 'percent'),
#  ('percent', 'of'),
#  ('of', 'homeless'),
#  ('homeless', 'people'),
#  ('people', 'surveyed'),
#  ('surveyed', 'cited'),
#  ('cited', '“could'),
#  ('“could', 'not'),
#  ('not', 'afford'),
#  ('afford', 'rent'),
#  ('rent', 'increase”'),
#  ('increase”', 'as'),
#  ('as', 'the'),
#  ('the', 'precipitating'),
#  ('precipitating', 'cause'),
#  ('cause', 'of'),
#  ('of', 'their'),
#  ('their', 'situation,'),
#  ('situation,', 'pointing'),
#  ('pointing', 'instead'),
#  ('instead', 'to'),
#  ('to', 'a'),
#  ('a', 'wide'),
#  ('wide', 'range'),
#  ('range', 'of'),
#  ('of', 'other'),
#  ('other', 'problems—domestic'),
#  ('problems—domestic', 'violence,'),
#  ('violence,', 'incarceration,'),
#  ('incarceration,', 'mental'),
#  ('mental', 'illness,'),
#  ('illness,', 'family'),
#  ('family', 'conflict,'),
#  ('conflict,', 'medical'),
#  ('medical', 'conditions,'),
#  ('conditions,', 'breakups,'),
#  ('breakups,', 'eviction,'),
#  ('eviction,', 'addiction,'),
#  ('addiction,', 'and'),
#  ('and', 'job'),
#  ('job', 'loss—as'),
#  ('loss—as', 'bigger'),
#  ('bigger', 'factors.'),
#  ('factors.', 'further,'),
#  ('further,', 'while'),
#  ('while', 'the'),
#  ('the', 'zillow'),
#  ('zillow', 'study'),
#  ('study', 'did'),
#  ('did', 'find'),
#  ('find', 'correlation'),
#  ('correlation', 'between'),
#  ('between', 'rising'),
#  ('rising', 'rents'),
#  ('rents', 'and'),
#  ('and', 'homelessness'),
#  ('homelessness', 'in'),
#  ('in', 'four'),
#  ('four', 'major'),
#  ('major', 'markets—seattle,'),
#  ('markets—seattle,', 'los'),
#  ('los', 'angeles,'),
#  ('angeles,', 'new'),
#  ('new', 'york,'),
#  ('york,', 'and'),
#  ('and', 'washington,'),
#  ('washington,', 'd.c.—it'),
#  ('d.c.—it', 'also'),
#  ('also', 'found'),
#  ('found', 'that'),
#  ('that', 'homelessness'),
#  ('homelessness', 'decreased'),
#  ('decreased', 'despite'),
#  ('despite', 'rising'),
#  ('rising', 'rents'),
#  ('rents', 'in'),
#  ('in', 'houston,'),
#  ('houston,', 'tampa,'),
#  ('tampa,', 'chicago,'),
#  ('chicago,', 'phoenix,'),
#  ('phoenix,', 'st.'),
#  ('st.', 'louis,'),
#  ('louis,', 'san'),
#  ('san', 'diego,'),
#  ('diego,', 'portland,'),
#  ('portland,', 'detroit,'),
#  ('detroit,', 'baltimore,'),
#  ('baltimore,', 'atlanta,'),
#  ('atlanta,', 'charlotte,'),
#  ('charlotte,', 'and'),
#  ('and', 'riverside.'),
#  ('riverside.', 'rent'),
#  ('rent', 'increases'),
#  ('increases', 'are'),
#  ('are', 'a'),
#  ('a', 'real'),
#  ('real', 'burden'),
#  ('burden', 'for'),
#  ('for', 'the'),
#  ('the', 'working'),
#  ('working', 'poor,'),
#  ('poor,', 'but'),
#  ('but', 'the'),
#  ('the', 'evidence'),
#  ('evidence', 'suggests'),
#  ('suggests', 'that'),
#  ('that', 'higher'),
#  ('higher', 'rents'),
#  ('rents', 'alone'),
#  ('alone', 'don’t'),
#  ('don’t', 'push'),
#  ('push', 'people'),
#  ('people', 'onto'),
#  ('onto', 'the'),
#  ('the', 'streets.'),
#  ('even', 'in'),
#  ('in', 'a'),
#  ('a', 'pricey'),
#  ('pricey', 'city'),
#  ('city', 'like'),
#  ('like', 'seattle,'),
#  ('seattle,', 'most'),
#  ('most', 'working-'),
#  ('working-', 'and'),
#  ('and', 'middle-class'),
#  ('middle-class', 'residents'),
#  ('residents', 'respond'),
#  ('respond', 'to'),
#  ('to', 'economic'),
#  ('economic', 'incentives'),
#  ('incentives', 'in'),
#  ('in', 'logical'),
#  ('logical', 'ways:'),
#  ('ways:', 'relocating'),
#  ('relocating', 'to'),
#  ('to', 'less'),
#  ('less', 'expensive'),
#  ('expensive', 'neighborhoods,'),
#  ('neighborhoods,', 'downsizing'),
#  ('downsizing', 'to'),
#  ('to', 'smaller'),
#  ('smaller', 'apartments,'),
#  ('apartments,', 'taking'),
#  ('taking', 'in'),
#  ('in', 'roommates,'),
#  ('roommates,', 'moving'),
#  ('moving', 'in'),
#  ('in', 'with'),
#  ('with', 'family,'),
#  ('family,', 'or'),
#  ('or', 'leaving'),
#  ('leaving', 'the'),
#  ('the', 'city'),
#  ('city', 'altogether.'),
#  ('altogether.', 'king'),
#  ('king', 'county'),
#  ('county', 'is'),
#  ('is', 'home'),
#  ('home', 'to'),
#  ('to', 'more'),
#  ('more', 'than'),
#  ('than', '1'),
#  ('1', 'million'),
#  ('million', 'residents'),
#  ('residents', 'earning'),
#  ('earning', 'below'),
#  ('below', 'the'),
#  ('the', 'median'),
#  ('median', 'income,'),
#  ('income,', 'and'),
#  ('and', '99'),
#  ('99', 'percent'),
#  ('percent', 'of'),
#  ('of', 'them'),
#  ('them', 'manage'),
#  ('manage', 'to'),
#  ('to', 'find'),
#  ('find', 'a'),
#  ('a', 'place'),
#  ('place', 'to'),
#  ('to', 'live'),
#  ('live', 'and'),
#  ('and', 'pay'),
#  ('pay', 'the'),
#  ('the', 'rent'),
#  ('rent', 'on'),
#  ('on', 'time.'),
#  ('time.', 'the'),
#  ('the', 'aggregate-level'),
#  ('aggregate-level', 'analyses'),
#  ('analyses', 'from'),
#  ('from', 'zillow'),
#  ('zillow', 'and'),
#  ('and', 'mckinsey'),
#  ('mckinsey', 'don’t'),
#  ('don’t', 'take'),
#  ('take', 'into'),
#  ('into', 'account'),
#  ('account', 'the'),
#  ('the', 'vast'),
#  ('vast', 'number'),
#  ('number', 'of'),
#  ('of', 'options'),
#  ('options', 'available'),
#  ('available', 'even'),
#  ('even', 'to'),
#  ('to', 'the'),
#  ('the', 'poorest'),
#  ('poorest', 'families;'),
#  ('families;', 'for'),
#  ('for', 'the'),
#  ('the', 'socialists,'),
#  ('socialists,', '“the'),
#  ('“the', 'rent'),
#  ('rent', 'is'),
#  ('is', 'too'),
#  ('too', 'damn'),
#  ('damn', 'high”'),
#  ('high”', 'explains'),
#  ('explains', 'everything.'),
#  ('using', 'homelessness'),
#  ('homelessness', 'as'),
#  ('as', 'a'),
#  ('a', 'symbol'),
#  ('symbol', 'of'),
#  ('of', '“capitalism’s'),
#  ('“capitalism’s', 'moral'),
#  ('moral', 'failure,”'),
#  ('failure,”', 'the'),
#  ('the', 'socialists'),
#  ('socialists', 'hope'),
#  ('hope', 'to'),
#  ('to', 'build'),
#  ('build', 'support'),
#  ('support', 'for'),
#  ('for', 'their'),
#  ('their', 'agenda'),
#  ('agenda', 'of'),
#  ('of', 'rent'),
#  ('rent', 'control,'),
#  ('control,', 'public'),
#  ('public', 'housing,'),
#  ('housing,', 'minimum-wage'),
#  ('minimum-wage', 'hikes,'),
#  ('hikes,', 'and'),
#  ('and', 'punitive'),
#  ('punitive', 'corporate'),
#  ('corporate', 'taxation.'),
#  ('taxation.', 'one'),
#  ('one', 'might'),
#  ('might', 'dismiss'),
#  ('dismiss', 'sawant'),
#  ('sawant', 'as'),
#  ('as', 'cartoonish,'),
#  ('cartoonish,', 'but'),
#  ('but', 'she'),
#  ('she', 'has'),
#  ('has', 'been'),
#  ('been', 'remarkably'),
#  ('remarkably', 'successful'),
#  ('successful', 'in'),
#  ('in', 'stoking'),
#  ('stoking', 'resentment'),
#  ('resentment', 'against'),
#  ('against', '“amazon'),
#  ('“amazon', 'tech'),
#  ('tech', 'bros”'),
#  ('bros”', 'and'),
#  ('and', 'building'),
#  ('building', 'public'),
#  ('public', 'support'),
#  ('support', 'for'),
#  ('for', 'punishing'),
#  ('punishing', 'the'),
#  ('the', '“billionaire'),
#  ('“billionaire', 'class”'),
#  ('class”', 'with'),
#  ('with', 'new'),
#  ('new', 'taxes.'),
#  ('what', 'the'),
#  ('the', 'socialists'),
#  ('socialists', 'won’t,'),
#  ('won’t,', 'or'),
#  ('or', 'can’t,'),
#  ('can’t,', 'see'),
#  ('see', 'is'),
#  ('is', 'that'),
#  ('that', 'their'),
#  ('their', 'agenda'),
#  ('agenda', 'cannot'),
#  ('cannot', 'solve'),
#  ('solve', 'the'),
#  ('the', 'homelessness'),
#  ('homelessness', 'crisis.'),
#  ('crisis.', 'even'),
#  ('even', 'if'),
#  ('if', 'the'),
#  ('the', 'sawant-championed'),
#  ('sawant-championed', '“head'),
#  ('“head', 'tax”'),
#  ('tax”', 'on'),
#  ('on', 'big'),
#  ('big', 'employers'),
#  ('employers', 'had'),
#  ('had', 'stayed'),
#  ('stayed', 'in'),
#  ('in', 'force—it'),
#  ('force—it', 'was'),
#  ('was', 'repealed'),
#  ('repealed', 'in'),
#  ('in', 'june—the'),
#  ('june—the', 'city'),
#  ('city', 'would'),
#  ('would', 'have'),
#  ('have', 'built,'),
#  ('built,', 'at'),
#  ('at', 'most,'),
#  ('most,', 'only'),
#  ('only', '187'),
#  ('187', 'subsidized'),
#  ('subsidized', 'housing'),
#  ('housing', 'units'),
#  ('units', 'per'),
#  ('per', 'year,'),
#  ('year,', 'which'),
#  ('which', 'means'),
#  ('means', 'that'),
#  ('that', 'it'),
#  ('it', 'would'),
#  ('would', 'take'),
#  ('take', 'at'),
#  ('at', 'least'),
#  ('least', '60'),
#  ('60', 'years'),
#  ('years', 'to'),
#  ('to', 'provide'),
#  ('provide', 'housing'),
#  ('housing', 'for'),
#  ('for', 'all'),
#  ('all', 'those'),
#  ('those', 'currently'),
#  ('currently', 'homeless.'),
#  ('homeless.', 'sawant’s'),
#  ('sawant’s', 'real'),
#  ('real', 'passion,'),
#  ('passion,', 'it'),
#  ('it', 'seems,'),
#  ('seems,', 'is'),
#  ('is', 'not'),
#  ('not', 'to'),
#  ('to', 'build'),
#  ('build', 'houses'),
#  ('houses', 'for'),
#  ('for', 'the'),
#  ('the', 'poor'),
#  ('poor', 'but'),
#  ('but', 'to'),
#  ('to', 'tear'),
#  ('tear', 'down'),
#  ('down', 'the'),
#  ('the', 'houses'),
#  ('houses', 'of'),
#  ('of', 'the'),
#  ('the', 'rich.'),
#  ('rich.', 'when'),
#  ('when', 'her'),
#  ('her', 'ideas'),
#  ('ideas', 'fail'),
#  ('fail', 'to'),
#  ('to', 'usher'),
#  ('usher', 'in'),
#  ('in', 'a'),
#  ('a', 'socialist'),
#  ('socialist', 'utopia,'),
#  ('utopia,', 'she’ll'),
#  ('she’ll', 'find'),
#  ('find', 'new'),
#  ('new', 'scapegoats—corporations,'),
#  ('scapegoats—corporations,', 'real-estate'),
#  ('real-estate', 'developers,'),
#  ('developers,', 'tech'),
#  ('tech', 'workers,'),
#  ('workers,', 'police—and'),
#  ('police—and', 'start'),
#  ('start', 'over.'),
#  ('the', 'stubborn'),
#  ('stubborn', 'reality'),
#  ('reality', 'is'),
#  ('is', 'that'),
#  ('that', 'seattle'),
#  ('seattle', 'is'),
#  ('is', 'expensive.'),
#  ('expensive.', 'the'),
#  ('the', 'local'),
#  ('local', 'government'),
#  ('government', 'should'),
#  ('should', 'encourage'),
#  ('encourage', 'the'),
#  ('the', 'creation'),
#  ('creation', 'of'),
#  ('of', 'more'),
#  ('more', 'affordable'),
#  ('affordable', 'market-rate'),
#  ('market-rate', 'housing'),
#  ('housing', 'by'),
#  ('by', 'increasing'),
#  ('increasing', 'density'),
#  ('density', 'and'),
#  ('and', 'changing'),
#  ('changing', 'zoning'),
#  ('zoning', 'laws,'),
#  ('laws,', 'but'),
#  ('but', 'for'),
#  ('for', 'those'),
#  ('those', 'not'),
#  ('not', 'employed'),
#  ('employed', 'full-time—and'),
#  ('full-time—and', 'that'),
#  ('that', 'describes'),
#  ('describes', '92.5'),
#  ('92.5', 'percent'),
#  ('percent', 'of'),
#  ('of', 'the'),
#  ('the', 'homeless—it’s'),
#  ('homeless—it’s', 'utopian'),
#  ('utopian', 'to'),
#  ('to', 'imagine'),
#  ('imagine', 'that'),
#  ('that', 'seattle'),
#  ('seattle', 'will'),
#  ('will', 'become'),
#  ('become', 'the'),
#  ('the', 'city'),
#  ('city', 'of'),
#  ('of', 'housing'),
#  ('housing', 'for'),
#  ('for', 'all.'),
#  ('all.', 'no'),
#  ('no', 'matter'),
#  ('matter', 'how'),
#  ('how', 'many'),
#  ('many', 'promises'),
#  ('promises', 'the'),
#  ('the', 'socialists'),
#  ('socialists', 'make,'),
#  ('make,', 'they'),
#  ('they', 'will'),
#  ('will', 'eventually'),
#  ('eventually', 'run'),
#  ('run', 'out'),
#  ('out', 'of'),
#  ('of', 'other'),
#  ('other', 'people’s'),
#  ('people’s', 'money.'),
#  ('money.', 'the'),
#  ('the', 'scapegoats,'),
#  ('scapegoats,', 'silent'),
#  ('silent', 'up'),
#  ('up', 'to'),
#  ('to', 'now,'),
#  ('now,', 'will'),
#  ('will', 'start'),
#  ('start', 'fighting'),
#  ('fighting', 'back.'),
#  ('back.', 'and'),
#  ('and', 'amazon,'),
#  ('amazon,', 'the'),
#  ('the', 'greatest'),
#  ('greatest', 'wealth'),
#  ('wealth', 'generator'),
#  ('generator', 'in'),
#  ('in', 'the'),
#  ('the', 'city’s'),
#  ('city’s', 'history,'),
#  ('history,', 'will'),
#  ('will', 'simply'),
#  ('simply', 'leave'),
#  ('leave', 'town.'),
#  ('“what', 'the'),
#  ('the', 'socialists'),
#  ('socialists', 'won’t,'),
#  ('won’t,', 'or'),
#  ('or', 'can’t,'),
#  ('can’t,', 'see'),
#  ('see', 'is'),
#  ('is', 'that'),
#  ('that', 'their'),
#  ('their', 'agenda'),
#  ('agenda', 'cannot'),
#  ('cannot', 'solve'),
#  ('solve', 'the'),
#  ('the', 'homelessness'),
#  ('homelessness', 'crisis.”'),
#  ('the', 'compassion'),
#  ('compassion', 'brigades'),
#  ...]

# %%
pairWords_clean = [gram for gram in pairWords if not any(stop in gram for stop in STOPS)]
print(pairWords_clean)
# Out:
# [('past', 'five'), ('five', 'years,'), ('emerald', 'city'), ('homelessness,', 'crime,'), ('2017', 'point-in-time'), ('point-in-time', 'count'), ('homeless,', 'king'), ('king', 'county'), ('county', 'social-services'), ('social-services', 'agency'), ('home', 'found'), ('found', '11,643'), ('11,643', 'people'), ('people', 'sleeping'), ('tents,', 'cars,'), ('emergency', 'shelters.'), ('shelters.', 'property'), ('property', 'crime'), ('rate', 'two'), ('half', 'times'), ('times', 'higher'), ('los', 'angeles’s'), ('four', 'times'), ('times', 'higher'), ('new', 'york'), ('york', 'city’s.'), ('city’s.', 'cleanup'), ('cleanup', 'crews'), ('crews', 'pick'), ('dirty', 'needles'), ('city', 'streets'), ('parks', 'every'), ('every', 'year.'), ('time,', 'according'), ('puget', 'sound'), ('sound', 'business'), ('business', 'journal,'), ('seattle', 'metro'), ('metro', 'area'), ('area', 'spends'), ('$1', 'billion'), ('billion', 'fighting'), ('fighting', 'homelessness'), ('homelessness', 'every'), ('every', 'year.'), ('year.', 'that’s'), ('that’s', 'nearly'), ('nearly', '$100,000'), ('every', 'homeless'), ('homeless', 'man,'), ('man,', 'woman,'), ('king', 'county,'), ('county,', 'yet'), ('crisis', 'seems'), ('tent', 'encampments'), ('residential', 'neighborhoods.'), ('city’s', 'efforts'), ('past', 'year,'), ('year,', 'i’ve'), ('i’ve', 'spent'), ('spent', 'time'), ('city', 'council'), ('council', 'meetings,'), ('meetings,', 'political'), ('political', 'rallies,'), ('rallies,', 'homeless'), ('homeless', 'encampments,'), ('rehabilitation', 'facilities,'), ('facilities,', 'trying'), ('much', 'money'), ('little', 'effect.'), ('tactical', 'policy'), ('policy', 'questions'), ('questions', '(build'), ('shelters?', 'open'), ('open', 'supervised'), ('supervised', 'injection'), ('injection', 'sites?),'), ('real', 'battle'), ('battle', 'isn’t'), ('city', 'hall'), ('ideas,', 'where,'), ('now,', 'four'), ('four', 'ideological'), ('ideological', 'power'), ('power', 'centers'), ('centers', 'frame'), ('frame', 'seattle’s'), ('seattle’s', 'homelessness'), ('homelessness', 'debate.'), ('debate.', 'i’ll'), ('i’ll', 'identify'), ('compassion', 'brigades,'), ('homeless-industrial', 'complex,'), ('addiction', 'evangelists.'), ('evangelists.', 'together,'), ('local', 'policy'), ('policy', 'discussion,'), ('discussion,', 'diverted'), ('diverted', 'hundreds'), ('dollars', 'toward'), ('toward', 'favored'), ('favored', 'projects,'), ('converted', 'many'), ('many', 'well-intentioned'), ('well-intentioned', 'voters'), ('unlimited', 'compassion.'), ('failed', 'status'), ('status', 'quo'), ('places', 'like'), ('like', 'seattle—and'), ('portland,', 'san'), ('san', 'francisco,'), ('los', 'angeles,'), ('angeles,', 'too—we'), ('too—we', 'must'), ('must', 'first'), ('first', 'map'), ('ideological', 'battlefield,'), ('battlefield,', 'identify'), ('current', 'policies,'), ('liberal', 'locales,'), ('recent', 'years,'), ('marched', 'even'), ('declared', 'war'), ('democratic', 'establishment.'), ('establishment.', 'socialist'), ('socialist', 'alternative'), ('alternative', 'city'), ('city', 'councilwoman'), ('councilwoman', 'kshama'), ('kshama', 'sawant'), ('sawant', 'claims'), ('city’s', 'homelessness'), ('homelessness', 'crisis'), ('inevitable', 'result'), ('amazon', 'boom,'), ('boom,', 'greedy'), ('greedy', 'landlords,'), ('rapidly', 'increasing'), ('increasing', 'rents.'), ('told', 'street'), ('street', 'roots'), ('roots', 'news:'), ('news:', '“the'), ('“the', 'explosion'), ('homelessness', 'crisis'), ('deeply', 'dysfunctional'), ('dysfunctional', 'capitalism'), ('much', 'worse'), ('worse', 'living'), ('living', 'standards'), ('last', 'several'), ('several', 'decades.”'), ('amazon,', 'starbucks,'), ('starbucks,', 'microsoft,'), ('marxian', 'optic,'), ('optic,', 'generate'), ('generate', 'enormous'), ('enormous', 'wealth'), ('themselves,', 'drive'), ('housing', 'prices,'), ('working', 'class'), ('class', 'toward'), ('toward', 'poverty'), ('often,', 'onto'), ('internal', 'logic.'), (' ...

# %%
# frequency of bigrams
from collections import Counter

bigramsCount_dict = Counter(pairWords_clean) #generate counter

# Turn bigramsCount_dict  into dataframe, naming columns
bigramsCount = pd.DataFrame(bigramsCount_dict.most_common(),
                        columns=['theBigram', 'weight'])
bigramsCount
# Out:
#                             theBigram  weight
# 0                      (king, county)       6
# 1            (addiction, evangelists)       6
# 2                   (harm, reduction)       5
# 3                       ($1, billion)       3
# 4     (homeless-industrial, complex,)       3
# ...                               ...     ...
# 1458                   (live,, work,)       1
# 1459      (flourishing, environment?)       1
# 1460          (homelessness, crisis,)       1
# 1461             (whether, political)       1
# 1462             (political, leaders)       1
#
# [1463 rows x 2 columns]

# %%
bigramsCount['word1'], bigramsCount['word2'] =zip(*bigramsCount['theBigram'])
bigramsCount
# Out:
#                             theBigram  weight                word1  \
# 0                      (king, county)       6                 king
# 1            (addiction, evangelists)       6            addiction
# 2                   (harm, reduction)       5                 harm
# 3                       ($1, billion)       3                   $1
# 4     (homeless-industrial, complex,)       3  homeless-industrial
# ...                               ...     ...                  ...
# 1458                   (live,, work,)       1                live,
# 1459      (flourishing, environment?)       1          flourishing
# 1460          (homelessness, crisis,)       1         homelessness
# 1461             (whether, political)       1              whether
# 1462             (political, leaders)       1            political
#
#              word2
# 0           county
# 1      evangelists
# 2        reduction
# 3          billion
# 4         complex,
# ...            ...
# 1458         work,
# 1459  environment?
# 1460       crisis,
# 1461     political
# 1462       leaders
#
# [1463 rows x 4 columns]

# %%
import networkx as nx

G_bigram=nx.from_pandas_edgelist(df=bigramsCount, source='word1',target= 'word2',edge_attr= ["weight"])

# %%
# plotting graph (default layout)
nx.draw_networkx(G_bigram)

# %%
#subsetting
bigramsCount_wgte_3=bigramsCount[bigramsCount['weight']>=3]

G_bigram_wgte_3=nx.from_pandas_edgelist(df=bigramsCount_wgte_3, source='word1',target= 'word2',edge_attr= ["weight"])

# %%
#plotting    
fig, ax = plt.subplots(figsize=(10, 10))
pos = nx.spring_layout(G_bigram_wgte_3)

# Plot networks
nx.draw_networkx(G_bigram_wgte_3, pos,
                 edge_color='red',node_color='yellow',
                 node_size=100,with_labels = False,ax=ax)

# labels away from node
for word, freq in pos.items():
    x, y = freq[0]+.05, freq[1]+.03
    ax.text(x, y,s=word,horizontalalignment='center', 
            fontsize=13,rotation=30)
    
plt.show()

# %%
pos = nx.spring_layout(G_bigram_wgte_3, weight='weight',k=0.6)
nx.draw_networkx(G_bigram_wgte_3, pos)

for edge in G_bigram_wgte_3.edges(data='weight'):
    nx.draw_networkx_edges(G_bigram_wgte_3, pos, edgelist=[edge], width=2*edge[2])
